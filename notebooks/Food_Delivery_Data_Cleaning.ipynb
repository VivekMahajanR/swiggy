# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Load Data

# %%
# load the csv file

df = pd.read_csv("swiggy.csv")

df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  19-03-2022    11:30:00          11:45:00
# 1                    77.813237  25-03-2022    19:45:00          19:50:00
# 2                    77.688400  19-03-2022    08:30:00          08:45:00
# 3                    77.026494  05-04-2022    18:00:00          18:10:00
# 4                    80.289982  26-03-2022    13:30:00          13:45:00
#
#        Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0       conditions Sunny                High                   2
# 1      conditions Stormy                 Jam                   2
# 2  conditions Sandstorms                 Low                   0
# 3       conditions Sunny              Medium                   0
# 4      conditions Cloudy                High                   1
#
#   Type_of_order Type_of_vehicle multiple_deliveries Festival            City  \
# 0        Snack      motorcycle                    0      No           Urban
# 1        Snack         scooter                    1      No   Metropolitian
# 2       Drinks      motorcycle                    1      No           Urban
# 3       Buffet      motorcycle                    1      No   Metropolitian
# 4        Snack         scooter                    1      No   Metropolitian
#
#   Time_taken(min)
# 0        (min) 24
# 1        (min) 33
# 2        (min) 26
# 3        (min) 21
# 4        (min) 30

# %%
# shape of data
df.shape
# Out:
# (45593, 20)

# %%
# datatypes of columns

(
    df.dtypes
    .rename("Data Types")
)
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# Name: Data Types, dtype: object

# %%
# info about the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  object
#  3   Delivery_person_Ratings      45593 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
#  12  Road_traffic_density         45593 non-null  object
#  13  Vehicle_condition            45593 non-null  int64
#  14  Type_of_order                45593 non-null  object
#  15  Type_of_vehicle              45593 non-null  object
#  16  multiple_deliveries          45593 non-null  object
#  17  Festival                     45593 non-null  object
#  18  City                         45593 non-null  object
#  19  Time_taken(min)              45593 non-null  object
# dtypes: float64(4), int64(1), object(15)
# memory usage: 7.0+ MB

# %% [markdown]
# **Corrections**:
#
# 1. Age column should be numerical.
# 2. Ratings should be float.
# 3. Date and time columns should be date and time.
# 4. Vehicle conditions seems to be categorical column which is integer encoded.
# 5. Multiple deliveries should be integer column.
# 6. Target column should also be numbers.

# %%
# missing values in data

df.isna().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **There are no missing values in the data**

# %%
# sample 50 rows of data for viewing

df.sample(50)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 14079  0xada3      JAPRES18DEL01                   22                     4.6
# 44906  0xa736     PUNERES19DEL02                   31                     4.7
# 570    0x326e      MYSRES17DEL01                   21                     4.7
# 17696  0x131c      MYSRES03DEL03                   38                     4.3
# 30156  0xa91c      MYSRES15DEL03                   21                     4.8
# 3621   0x770f    PUNERES010DEL01                   35                     4.5
# 34891  0x59b7      SURRES16DEL02                   36                     4.8
# 17430  0x7b17      MYSRES11DEL02                   22                     4.7
# 23391  0xbf9b      KOCRES03DEL02                 NaN                     NaN
# 4166    0x890    COIMBRES04DEL02                   31                     4.1
# 24130  0x3c4a      HYDRES08DEL03                   28                     4.8
# 8684   0xb46e      MYSRES11DEL01                   21                       5
# 8138   0xd0b3      AGRRES08DEL03                   24                     4.6
# 23991  0xbf52      KOLRES06DEL01                 NaN                     NaN
# 45033  0xb270      VADRES14DEL02                   30                     4.6
# 7323   0x55af     CHENRES14DEL02                   29                       5
# 42136  0x9cd9     MYSRES010DEL03                   23                     4.7
# 3361   0x40fe     CHENRES05DEL02                   32                     4.7
# 24354  0x22c8      MYSRES03DEL02                   25                     4.2
# 29540   0x4cd      MYSRES11DEL02                 NaN                     NaN
# 33423  0x562e      MYSRES13DEL02                   21                     4.9
# 2800   0x925e     BANGRES13DEL01                   26                     4.7
# 30196  0xd8b4      AGRRES14DEL02                   30                     4.8
# 42161  0x9235      MUMRES08DEL03                   27                     4.5
# 1424   0x9412    COIMBRES19DEL01                   36                       4
# 35431  0x2026      SURRES03DEL02                   23                     4.7
# 3346   0xa0f2      JAPRES02DEL03                   23                       5
# 13537   0x7b2      SURRES12DEL02                   34                     4.3
# 39552  0x4847      SURRES02DEL03                   21                     4.8
# 13363  0xcca0      DEHRES20DEL03                   20                     4.6
# 31999  0xd908      AGRRES18DEL03                   32                     4.7
# 12513  0xa00b     BANGRES04DEL02                   32                     4.7
# 2800         Snack         motorcycle                    3      No
# 30196        Snack            scooter                    0      No
# 42161        Snack         motorcycle                    0      No
# 1424        Drinks         motorcycle                    0      No
# 35431       Buffet         motorcycle                    1      No
# 3346        Buffet         motorcycle                    1      No
# 13537       Buffet            scooter                    0      No
# 39552       Buffet            scooter                    0      No
# 13363       Buffet         motorcycle                    0      No
# 31999        Snack            scooter                    0      No
# 12513       Buffet            scooter                    1      No
# 43049        Snack            scooter                    1      No
# 35395       Buffet         motorcycle                    1      No
# 41898        Snack            scooter                 NaN       No
# 6026        Buffet            scooter                    0      No
# 3954        Buffet         motorcycle                    0      No
# 24183        Snack         motorcycle                 NaN       No
# 26205        Snack         motorcycle                    1      No
# 3725          Meal            scooter                    1      No
# 40066        Snack            scooter                    1      No
# 30083         Meal   electric_scooter                    1      No
# 7020         Snack            scooter                    0      No
# 18218       Buffet            scooter                    0      No
# 23624         Meal   electric_scooter                    1      No
# 21179        Snack         motorcycle                    1      No
# 28134         Meal         motorcycle                    2      No
# 41767        Snack         motorcycle                    1      No
# 25490         Meal            scooter                    1      No
# 32917       Buffet         motorcycle                    1      No
#
#                  City Time_taken(min)
# 14079          Urban         (min) 16
# 44906  Metropolitian         (min) 23
# 570    Metropolitian         (min) 35
# 17696  Metropolitian         (min) 37
# 30156  Metropolitian         (min) 12
# 3621           Urban         (min) 21
# 34891          Urban         (min) 19
# 17430  Metropolitian         (min) 30
# 23391          Urban         (min) 31
# 4166   Metropolitian         (min) 34
# 24130  Metropolitian         (min) 16
# 8684           Urban         (min) 18
# 8138           Urban         (min) 10
# 23991            NaN         (min) 11
# 45033  Metropolitian         (min) 41
# 7323   Metropolitian         (min) 26
# 42136  Metropolitian         (min) 12
# 3361   Metropolitian         (min) 12
# 24354  Metropolitian         (min) 33
# 29540  Metropolitian         (min) 43
# 33423  Metropolitian         (min) 30
# 2800   Metropolitian         (min) 48
# 30196  Metropolitian         (min) 17
# 42161  Metropolitian         (min) 22
# 1424   Metropolitian         (min) 37
# 35431  Metropolitian         (min) 22
# 3346   Metropolitian         (min) 11
# 13537  Metropolitian         (min) 37
# 39552  Metropolitian         (min) 18
# 13363  Metropolitian         (min) 14
# 31999          Urban         (min) 22
# 12513          Urban         (min) 20
# 43049  Metropolitian         (min) 23
# 35395  Metropolitian         (min) 49
# 41898          Urban         (min) 23
# 6026   Metropolitian         (min) 38
# 3954           Urban         (min) 11
# 24183  Metropolitian         (min) 24
# 26205  Metropolitian         (min) 40
# 3725   Metropolitian         (min) 12
# 40066  Metropolitian         (min) 24
# 30083  Metropolitian         (min) 38
# 7020   Metropolitian         (min) 34
# 18218  Metropolitian         (min) 19
# 23624          Urban         (min) 39
# 21179          Urban         (min) 25
# 28134          Urban         (min) 48
# 41767  Metropolitian         (min) 25
# 25490  Metropolitian         (min) 32
# 32917  Metropolitian         (min) 26

# %% [markdown]
# **NaN values in the data**
#
# Investigate further

# %% [markdown]
# # Missing values
#
# Missing values are string type in the data with an extra space.

# %%
df.loc[23991,"Delivery_person_Ratings"]
# Out:
# 'NaN '

# %%
# String NaNs in the data

(df == "NaN ").sum().sum()
# Out:
# np.int64(8515)

# %% [markdown]
# 8515 such NaN's in the data

# %%
# column wise string NaNs


(df == "NaN ").sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
# replace string NaN with NaN

df.replace("NaN ",np.nan)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                        75.912471  19-03-2022    11:30:00          11:45:00
# 1                        77.813237  25-03-2022    19:45:00          19:50:00
# 2                        77.688400  19-03-2022    08:30:00          08:45:00
# 3                        77.026494  05-04-2022    18:00:00          18:10:00
# 4                        80.289982  26-03-2022    13:30:00          13:45:00
# ...                            ...         ...         ...               ...
# 45588                    75.804257  24-03-2022    11:35:00          11:45:00
# 45589                     0.070000  16-02-2022    19:55:00          20:10:00
# 45590                    80.272439  11-03-2022    23:50:00          00:05:00
# 45591                    77.026241  07-03-2022    13:35:00          13:40:00
# 45592                    85.405731  02-03-2022    17:10:00          17:15:00
#
#            Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0           conditions Sunny                High                   2
# 1          conditions Stormy                 Jam                   2
# 2      conditions Sandstorms                 Low                   0
# 3           conditions Sunny              Medium                   0
# 4          conditions Cloudy                High                   1
# ...                      ...                  ...                ...
# 45588       conditions Windy                High                   1
# 45589       conditions Windy                 Jam                   0
# 45590      conditions Cloudy                 Low                   1
# 45591      conditions Cloudy                High                   0
# 45592         conditions Fog              Medium                   2
#
#       Type_of_order Type_of_vehicle multiple_deliveries Festival  \
# 0            Snack      motorcycle                    0      No
# 1            Snack         scooter                    1      No
# 2           Drinks      motorcycle                    1      No
# 3           Buffet      motorcycle                    1      No
# 4            Snack         scooter                    1      No
# ...             ...             ...                 ...      ...
# 45588         Meal      motorcycle                    0      No
# 45589       Buffet      motorcycle                    1      No
# 45590       Drinks         scooter                    0      No
# 45591        Snack      motorcycle                    1      No
# 45592        Snack         scooter                    1      No
#
#                  City Time_taken(min)
# 0              Urban         (min) 24
# 1      Metropolitian         (min) 33
# 2              Urban         (min) 26
# 3      Metropolitian         (min) 21
# 4      Metropolitian         (min) 30
# ...               ...             ...
# 45588  Metropolitian         (min) 32
# 45589  Metropolitian         (min) 36
# 45590  Metropolitian         (min) 16
# 45591  Metropolitian         (min) 26
# 45592  Metropolitian         (min) 36
#
# [45593 rows x 20 columns]

# %%
# verify missing values in the data

df.replace("NaN ",np.nan).isna().sum().sum()
# Out:
# np.int64(8515)

# %% [markdown]
# **Verified that string NaNs converted to Nan**

# %%
# NaN in the weather column
(
    df.loc[:,"Weatherconditions"]
    .str.replace("conditions ","")
    .replace("NaN",np.nan)
    .isna().sum()
)
# Out:
# np.int64(616)

# %% [markdown]
# **616 missing values in the weather column**

# %%
# df with all the missing values replace

missing_df = (
    df.replace("NaN ",np.nan)
    .assign(
        Weatherconditions = lambda df_ : (
            df_['Weatherconditions']
            .str.replace("conditions ","")
            .replace("NaN",np.nan)
            )
    )
)

missing_df
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                        75.912471  19-03-2022    11:30:00          11:45:00
# 1                        77.813237  25-03-2022    19:45:00          19:50:00
# 2                        77.688400  19-03-2022    08:30:00          08:45:00
# 3                        77.026494  05-04-2022    18:00:00          18:10:00
# 4                        80.289982  26-03-2022    13:30:00          13:45:00
# ...                            ...         ...         ...               ...
# 45588                    75.804257  24-03-2022    11:35:00          11:45:00
# 45589                     0.070000  16-02-2022    19:55:00          20:10:00
# 45590                    80.272439  11-03-2022    23:50:00          00:05:00
# 45591                    77.026241  07-03-2022    13:35:00          13:40:00
# 45592                    85.405731  02-03-2022    17:10:00          17:15:00
#
#       Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                 Sunny                High                   2        Snack
# 1                Stormy                 Jam                   2        Snack
# 2            Sandstorms                 Low                   0       Drinks
# 3                 Sunny              Medium                   0       Buffet
# 4                Cloudy                High                   1        Snack
# ...                 ...                  ...                ...           ...
# 45588             Windy                High                   1         Meal
# 45589             Windy                 Jam                   0       Buffet
# 45590            Cloudy                 Low                   1       Drinks
# 45591            Cloudy                High                   0        Snack
# 45592               Fog              Medium                   2        Snack
#
#       Type_of_vehicle multiple_deliveries Festival            City  \
# 0         motorcycle                    0      No           Urban
# 1            scooter                    1      No   Metropolitian
# 2         motorcycle                    1      No           Urban
# 3         motorcycle                    1      No   Metropolitian
# 4            scooter                    1      No   Metropolitian
# ...               ...                 ...      ...             ...
# 45588     motorcycle                    0      No   Metropolitian
# 45589     motorcycle                    1      No   Metropolitian
# 45590        scooter                    0      No   Metropolitian
# 45591     motorcycle                    1      No   Metropolitian
# 45592        scooter                    1      No   Metropolitian
#
#       Time_taken(min)
# 0            (min) 24
# 1            (min) 33
# 2            (min) 26
# 3            (min) 21
# 4            (min) 30
# ...               ...
# 45588        (min) 32
# 45589        (min) 36
# 45590        (min) 16
# 45591        (min) 26
# 45592        (min) 36
#
# [45593 rows x 20 columns]

# %% [markdown]
# Above code can be simplied this way
# missing_df = (
#     df.replace("NaN ", np.nan)  # First replace "NaN " strings with actual NaN in entire DataFrame
#     .assign(  # Then modify the DataFrame by...
#         Weatherconditions = lambda x: (  # reassigning the Weatherconditions column
#             x['Weatherconditions']  # Take the column values
#             .str.replace("conditions ", "")  # Remove "conditions " prefix
#             .replace("NaN", np.nan)  # Then replace any "NaN" strings with actual NaN
#         )
#     )
# )

# %%
# missing values in data

missing_df.isna().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
# total missing values in data

missing_df.isna().sum().sum()
# Out:
# np.int64(9131)

# %%
8515 + 616
# Out:
# 9131

# %% [markdown]
# ## Missing Value Analysis

# %% [markdown]
# ### Matrix

# %%
# missing values matrix

msno.matrix(missing_df)
# Out:
# <Axes: >

# %% [markdown]
# ### Count of Missing Values

# %%
# bar plot for columns having missing data
fig, ax = plt.subplots(figsize=(15, 6)) # Adjust the figure size as needed
msno.bar(missing_df, ax=ax, fontsize=8)
# Out:
# <Axes: >

# %% [markdown]
# ### Missing Corr

# %%
# missing data correlation

fig, ax = plt.subplots(figsize=(12, 6)) # Adjust the figure size as needed
msno.heatmap(missing_df, ax=ax, fontsize=8) # Add fontsize argument
# Out:
# <Axes: >

# %% [markdown]
# **Observations**
#
# 1. The delivery person columns are correlated to each other. This means that missingness in these columns is highly related which means lack of rider data.
# 2. The time ordered column is also related to the rider which shows that the data might be missing due to some network error where the system was unable to log rider details and time of order.
# 3. There is a very high correlation between weather patterns and the road traffic information. Be clear that this does not mean that the road traffic and weather columns are correlated. High corr in missingness means that if value in one column is missing, it is a high chance that it will be missing in others as well.
# 3. Road traffic density also shows correlation to the rider as it might be provided through the phone of rider (need to investigate).

# %% [markdown]
# 0 - along the series

# %% [markdown]
# 1 - Across the series

# %%
missing_df[["Weatherconditions","Road_traffic_density"]].isna().any(axis = 1).sum()
# Out:
# np.int64(616)

# %%
missing_df[["Weatherconditions","Road_traffic_density"]].isna().sum()
# Out:
# Weatherconditions       616
# Road_traffic_density    601
# dtype: int64

# %%
missing_df[["Weatherconditions","Road_traffic_density"]].isna().all(axis=1).sum()
# Out:
# np.int64(601)

# %%
(
    missing_df[["Weatherconditions","Road_traffic_density"]]
    .isna().all(axis=1)
    .sum()
)/(missing_df[["Weatherconditions","Road_traffic_density"]]
   .isna().sum()
)
# Out:
# Weatherconditions       0.975649
# Road_traffic_density    1.000000
# dtype: float64

# %% [markdown]
# ### Dendrogram

# %%
# dendrogram of missingness

msno.dendrogram(missing_df)
# Out:
# <Axes: >

# %%
print(f'Implies that {missing_df.isna().any(axis=0).sum()} columns missing values') #implies that 8 columns missing values
missing_df.isna().any(axis=0).loc[lambda x: x].index.to_list() # these 8 columns are iether to be imputed or dropped
# Out:
# Implies that 8 columns missing values
# ['Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Time_Orderd',
#  'Weatherconditions',
#  'Road_traffic_density',
#  'multiple_deliveries',
#  'Festival',
#  'City']

# %%
missing_df.isna().any(axis=1).sum() # these rows are having one or more NaN values
# Out:
# np.int64(4225)

# %%
missing_df.shape[0]
# Out:
# 45593

# %%
# percentage of rows in the data having missing value

(missing_df.isna().any(axis=1).sum() / missing_df.shape[0]) * 100
# Out:
# np.float64(9.266773408198627)

# %% [markdown]
# **About `9%` of the rows in the data have missing values**

# %% [markdown]
# # Basic Data Cleaning

# %%
# column names in data

df.columns.tolist()
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Weatherconditions',
#  'Road_traffic_density',
#  'Vehicle_condition',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'multiple_deliveries',
#  'Festival',
#  'City',
#  'Time_taken(min)']

# %%
def change_column_names(data: pd.DataFrame):
    return (
        data.rename(str.lower,axis=1)
        .rename({
            "delivery_person_id" : "rider_id",
            "delivery_person_age": "age",
            "delivery_person_ratings": "ratings",
            "delivery_location_latitude": "delivery_latitude",
            "delivery_location_longitude": "delivery_longitude",
            "time_orderd": "order_time",
            "time_order_picked": "order_picked_time",
            "weatherconditions": "weather",
            "road_traffic_density": "traffic",
            "city": "city_type",
            "time_taken(min)": "time_taken"},axis=1)
    )

# %%
## Deepseek
def change_column_names(data: pd.DataFrame):
    return data.rename(
        columns={
            **{col: col.lower() for col in data.columns},
            "delivery_person_id": "rider_id",
            "delivery_person_age": "age",
            "delivery_person_ratings": "ratings",
            "delivery_location_latitude": "delivery_latitude",
            "delivery_location_longitude": "delivery_longitude",
            "time_orderd": "order_time",
            "time_order_picked": "order_picked_time",
            "weatherconditions": "weather",
            "road_traffic_density": "traffic",
            "city": "city_type",
            "time_taken(min)": "time_taken"
        }
    )

# %%
# change column names

df = change_column_names(df)

# %%
df.head()
# Out:
#         id          rider_id age ratings  restaurant_latitude  \
# 0  0x4607    INDORES13DEL02   37     4.9            22.745049
# 1  0xb379    BANGRES18DEL02   34     4.5            12.913041
# 2  0x5d6d    BANGRES19DEL01   23     4.4            12.914264
# 3  0x7a6a   COIMBRES13DEL02   38     4.7            11.003669
# 4  0x70a2    CHENRES12DEL01   32     4.6            12.972793
#
#    restaurant_longitude  delivery_latitude  delivery_longitude  order_date  \
# 0             75.892471          22.765049           75.912471  19-03-2022
# 1             77.683237          13.043041           77.813237  25-03-2022
# 2             77.678400          12.924264           77.688400  19-03-2022
# 3             76.976494          11.053669           77.026494  05-04-2022
# 4             80.249982          13.012793           80.289982  26-03-2022
#
#   order_time order_picked_time                weather  traffic  \
# 0   11:30:00          11:45:00       conditions Sunny    High
# 1   19:45:00          19:50:00      conditions Stormy     Jam
# 2   08:30:00          08:45:00  conditions Sandstorms     Low
# 3   18:00:00          18:10:00       conditions Sunny  Medium
# 4   13:30:00          13:45:00      conditions Cloudy    High
#
#    vehicle_condition type_of_order type_of_vehicle multiple_deliveries  \
# 0                  2        Snack      motorcycle                    0
# 1                  2        Snack         scooter                    1
# 2                  0       Drinks      motorcycle                    1
# 3                  0       Buffet      motorcycle                    1
# 4                  1        Snack         scooter                    1
#
#   festival       city_type time_taken
# 0      No           Urban    (min) 24
# 1      No   Metropolitian    (min) 33
# 2      No           Urban    (min) 26
# 3      No   Metropolitian    (min) 21
# 4      No   Metropolitian    (min) 30

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check for duplicate rows

df.drop(columns=["id","rider_id"]).duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **There are no duplicate rows in the data**

# %% [markdown]
# ## Column Wise Cleaning

# %% [markdown]
# ### ID

# %%
df.shape[0]
# Out:
# 45593

# %%
# unique items in ID column

print(f"The number of unique IDs are {df['id'].nunique()}")
# Out:
# The number of unique IDs are 45593

# %% [markdown]
# **All the ID values are unique**
#
# This column can be dropped from the data

# %% [markdown]
# ### Rider Id

# %%
# unique rider ids in the column

df['rider_id'].nunique()
# Out:
# 1320

# %% [markdown]
# **The data contains 1320 unique riders**

# %%
# rider order count in data

df['rider_id'].value_counts().head(490)
# Out:
# rider_id
# PUNERES01DEL01       67
# JAPRES11DEL02        67
# VADRES08DEL02        66
# RANCHIRES02DEL01     66
# HYDRES04DEL02        66
#                      ..
# HYDRES19DEL02        51
# MUMRES06DEL01        51
# INDORES14DEL01       50
# JAPRES010DEL02       50
# INDORES12DEL02       50
# Name: count, Length: 490, dtype: int64

# %%
# extract city name out of rider id

(
    df['rider_id']
    .str.split("RES")
    .str.get(0)
    .rename("City_Name")
)
# Out:
# 0          INDO
# 1          BANG
# 2          BANG
# 3         COIMB
# 4          CHEN
#           ...
# 45588       JAP
# 45589       AGR
# 45590      CHEN
# 45591     COIMB
# 45592    RANCHI
# Name: City_Name, Length: 45593, dtype: object

# %%
df['city_name'] = df['rider_id'].str.split("RES").str.get(0).rename("City_Name")
df.head(3)
# Out:
#         id         rider_id age ratings  restaurant_latitude  \
# 0  0x4607   INDORES13DEL02   37     4.9            22.745049
# 1  0xb379   BANGRES18DEL02   34     4.5            12.913041
# 2  0x5d6d   BANGRES19DEL01   23     4.4            12.914264
#
#    restaurant_longitude  delivery_latitude  delivery_longitude  order_date  \
# 0             75.892471          22.765049           75.912471  19-03-2022
# 1             77.683237          13.043041           77.813237  25-03-2022
# 2             77.678400          12.924264           77.688400  19-03-2022
#
#   order_time  ...                weather traffic vehicle_condition  \
# 0   11:30:00  ...       conditions Sunny   High                  2
# 1   19:45:00  ...      conditions Stormy    Jam                  2
# 2   08:30:00  ...  conditions Sandstorms    Low                  0
#
#    type_of_order type_of_vehicle multiple_deliveries festival       city_type  \
# 0         Snack      motorcycle                    0      No           Urban
# 1         Snack         scooter                    1      No   Metropolitian
# 2        Drinks      motorcycle                    1      No           Urban
#
#   time_taken city_name
# 0   (min) 24      INDO
# 1   (min) 33      BANG
# 2   (min) 26      BANG
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Age

# %%
# datatype

df['age'].dtype
# Out:
# dtype('O')

# %%
# min, mean and max values

df['age'].astype(float).describe()
# Out:
# count    43739.000000
# mean        29.567137
# std          5.815155
# min         15.000000
# 25%         25.000000
# 50%         30.000000
# 75%         35.000000
# max         50.000000
# Name: age, dtype: float64

# %% [markdown]
# **Minimum Rider age of 15 is concerning**
#
# Investigate further what type of transport is he using?

# %%
# boxplot of the age column

sns.boxplot(df['age'].astype(float))
# Out:
# <Axes: ylabel='age'>

# %%
# rows of data where rider age is less than 18(minor)


minors_data = df.loc[df['age'].astype('float') < 18]

minors_data
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 2387    0x564      JAPRES15DEL03   15       1           -26.891191
# 2905    0xcd0    INDORES010DEL03   15       1            22.750040
# 2951    0x91a      SURRES17DEL03   15       1            21.149569
# 5902    0x474     CHENRES15DEL03   15       1            13.026286
# 9156    0x73f     BANGRES05DEL01   15       1            12.970324
# 10900  0x1b49      MUMRES14DEL02   15       1            19.181300
# 11125   0x40b      SURRES12DEL01   15       1           -21.183434
# 12093   0x523     INDORES03DEL02   15       1            22.751857
# 15124  0x18b0   RANCHIRES02DEL01   15       1             0.000000
# 15927   0x550     CHENRES08DEL02   15       1            13.022394
# 16084   0x58c      MUMRES02DEL01   15       1           -19.221315
# 16462   0xe4c      MYSRES05DEL03   15       1            12.323978
# 21222   0x3fc     BANGRES16DEL02   15       1            13.029198
# 22291   0x3ed   RANCHIRES09DEL01   15       1           -23.351058
# 23035   0x415      VADRES17DEL01   15       1             0.000000
# 23488  0x616c      SURRES07DEL02   15       1            21.170798
# 23644  0x1ea0     BANGRES17DEL02   15       1            12.972532
# 23664   0x3f7     CHENRES04DEL01   15       1           -13.029780
# 25873   0xbb3     CHENRES15DEL03   15       1            13.026286
# 26633   0x730     INDORES15DEL02   15       1            22.760072
# 26917   0x6e0     CHENRES06DEL03   15       1            13.054347
# 27118   0x3f2     BANGRES02DEL02   15       1            12.970221
# 29664        Drinks            scooter                    1      No
# 31216         Snack   electric_scooter                    1      No
# 31959          Meal            bicycle                    0      No
# 33198        Buffet            scooter                    0      No
# 34953         Snack            scooter                    1      No
# 36021          Meal         motorcycle                    1      No
# 37100        Buffet   electric_scooter                    1      No
# 37676        Buffet            scooter                    1      No
# 39073        Drinks   electric_scooter                    0      No
# 39082         Snack   electric_scooter                    0      No
# 40285         Snack            bicycle                    0      No
# 41241          Meal            scooter                    0      No
# 44403        Drinks            scooter                    0      No
# 44881         Snack   electric_scooter                    1      No
#
#             city_type time_taken city_name
# 2387           Urban    (min) 15       JAP
# 2905   Metropolitian    (min) 29      INDO
# 2951   Metropolitian    (min) 20       SUR
# 5902   Metropolitian    (min) 25      CHEN
# 9156   Metropolitian    (min) 34      BANG
# 10900  Metropolitian    (min) 39       MUM
# 11125          Urban    (min) 27       SUR
# 12093  Metropolitian    (min) 28      INDO
# 15124  Metropolitian    (min) 21    RANCHI
# 15927  Metropolitian    (min) 17      CHEN
# 16084  Metropolitian    (min) 23       MUM
# 16462          Urban    (min) 24       MYS
# 21222  Metropolitian    (min) 28      BANG
# 22291  Metropolitian    (min) 44    RANCHI
# 23035          Urban    (min) 27       VAD
# 23488  Metropolitian    (min) 32       SUR
# 23644  Metropolitian    (min) 23      BANG
# 23664          Urban    (min) 15      CHEN
# 25873  Metropolitian    (min) 27      CHEN
# 26633  Metropolitian    (min) 27      INDO
# 26917          Urban    (min) 21      CHEN
# 27118          Urban    (min) 20      BANG
# 27942  Metropolitian    (min) 27      CHEN
# 28003  Metropolitian    (min) 38      PUNE
# 29664  Metropolitian    (min) 13       MYS
# 31216          Urban    (min) 19       JAP
# 31959  Metropolitian    (min) 21      PUNE
# 33198  Metropolitian    (min) 33      CHEN
# 34953  Metropolitian    (min) 19     COIMB
# 36021  Metropolitian    (min) 28     COIMB
# 37100          Urban    (min) 30       HYD
# 37676          Urban    (min) 30      PUNE
# 39073  Metropolitian    (min) 24     COIMB
# 39082  Metropolitian    (min) 30       MYS
# 40285  Metropolitian    (min) 25      CHEN
# 41241  Metropolitian    (min) 25     COIMB
# 44403  Metropolitian    (min) 34       VAD
# 44881          Urban    (min) 26      CHEN
#
# [38 rows x 21 columns]

# %% [markdown]
# **Observations**:
#
# 1. The star ratings of all the riders is 1.
# 2. The vehicle condition of these riders is very bad.
# 3. No weather and traffic conditions available.
# 4. Age of all these riders is 15 which is below the permissable age to drive a vehicle.
# 5. Latitude and Longitude values in negative which is not possible. India is situated above the equator so all latitudes should be positive and east of meridian line so longitudes are positive as well.

# %% [markdown]
# **Seems like removing this data for now makes more sense then fixing it because a lot of data is missing**

# %%
# rows of minors

minor_index = minors_data.index.tolist()

len(minor_index)
# Out:
# 38

# %% [markdown]
# ### Ratings

# %%
# datatype

df['ratings'].dtype
# Out:
# dtype('O')

# %%
# min, mean and max values

df['ratings'].astype(float).describe()
# Out:
# count    43685.000000
# mean         4.633780
# std          0.334716
# min          1.000000
# 25%          4.500000
# 50%          4.700000
#
#        type_of_order    type_of_vehicle multiple_deliveries festival  \
# 3586           Meal   electric_scooter                    0      No
# 4714          Snack            bicycle                    0      No
# 5169         Drinks            scooter                    1      No
# 5362           Meal   electric_scooter                    1      No
# 5651         Drinks            scooter                    1      No
# 6394           Meal   electric_scooter                    0      No
# 7031         Buffet            scooter                    1      No
# 7681           Meal            bicycle                    1      No
# 9499         Drinks            scooter                    1      No
# 9535          Snack            bicycle                    1      No
# 10100         Snack   electric_scooter                    1      No
# 10737         Snack            scooter                    0      No
# 12297          Meal            scooter                    1      No
# 13257        Buffet   electric_scooter                    1      No
# 13652        Buffet         motorcycle                    0      No
# 14106          Meal            scooter                    0      No
# 14907        Drinks            bicycle                    0      No
# 14944          Meal         motorcycle                    1      No
# 16798        Drinks            scooter                    1      No
# 17145         Snack   electric_scooter                    0      No
# 17708        Drinks   electric_scooter                    1      No
# 18977        Buffet            scooter                    1      No
# 19382        Drinks            bicycle                    0      No
# 20269         Snack         motorcycle                    1      No
# 21320        Drinks   electric_scooter                    1      No
# 22416        Drinks            scooter                    0      No
# 23375        Buffet   electric_scooter                    0      No
# 24237          Meal         motorcycle                    0      No
# 24918        Buffet            scooter                    1      No
# 25285          Meal   electric_scooter                    0      No
# 26052          Meal   electric_scooter                    0      No
# 27221        Drinks   electric_scooter                    0      No
# 27399          Meal   electric_scooter                    1      No
# 28315        Drinks   electric_scooter                    0      No
# 28974          Meal   electric_scooter                    0      No
# 29535        Drinks   electric_scooter                    1      No
# 30579         Snack            bicycle                    2      No
# 30943          Meal            scooter                    1      No
# 31233        Drinks            scooter                    0      No
# 32326        Drinks            scooter                    0      No
# 33533         Snack            scooter                    1      No
# 34688        Drinks   electric_scooter                    1      No
# 38007         Snack   electric_scooter                    1      No
# 38020          Meal            scooter                    0      No
# 38561        Drinks   electric_scooter                    0      No
# 38649        Buffet   electric_scooter                    1      No
# 39699        Buffet            bicycle                    1      No
# 40223        Drinks   electric_scooter                    1      No
# 41105          Meal            scooter                    1     Yes
# 41969        Drinks            scooter                    1      No
# 42072        Buffet            scooter                    0      No
# 42835        Drinks   electric_scooter                    1      No
# 45332        Drinks   electric_scooter                    1      No
#
#             city_type time_taken city_name
# 3586           Urban    (min) 25      BANG
# 4714   Metropolitian    (min) 27       HYD
# 5169   Metropolitian    (min) 20       JAP
# 5362   Metropolitian    (min) 18      BANG
# 5651   Metropolitian    (min) 20       AGR
# 6394           Urban    (min) 20       JAP
# 7031   Metropolitian    (min) 14       MYS
# 7681   Metropolitian    (min) 22       VAD
# 9499           Urban    (min) 17      BANG
# 9535   Metropolitian    (min) 32    RANCHI
# 10100  Metropolitian    (min) 35       MYS
# 10737  Metropolitian    (min) 25       DEH
# 12297          Urban    (min) 22       SUR
# 13257          Urban    (min) 11     COIMB
# 13652  Metropolitian    (min) 28    RANCHI
# 14106          Urban    (min) 15       MYS
# 14907  Metropolitian    (min) 12      CHEN
# 14944          Urban    (min) 19       HYD
# 16798  Metropolitian    (min) 22    RANCHI
# 17145          Urban    (min) 14     COIMB
# 17708  Metropolitian    (min) 20      CHEN
# 18977  Metropolitian    (min) 17       BHP
# 19382  Metropolitian    (min) 30      INDO
# 20269          Urban    (min) 33       ALH
# 21320  Metropolitian    (min) 35       HYD
# 22416  Metropolitian    (min) 29       ALH
# 23375          Urban    (min) 19      BANG
# 24237  Metropolitian    (min) 17       SUR
# 24918  Metropolitian    (min) 41       KNP
# 25285  Metropolitian    (min) 16     COIMB
# 26052  Metropolitian    (min) 20    RANCHI
# 27221            NaN    (min) 17     COIMB
# 27399  Metropolitian    (min) 18       MUM
# 28315  Metropolitian    (min) 28      BANG
# 28974  Metropolitian    (min) 20      CHEN
# 29535  Metropolitian    (min) 15      BANG
# 30579  Metropolitian    (min) 39       BHP
# 30943          Urban    (min) 30       MUM
# 31233  Metropolitian    (min) 28       VAD
# 32326            NaN    (min) 17       KNP
# 33533  Metropolitian    (min) 28       KOL
# 34688          Urban    (min) 16       AGR
# 38007  Metropolitian    (min) 25       DEH
# 38020  Metropolitian    (min) 14      CHEN
# 38561  Metropolitian    (min) 36       VAD
# 38649          Urban    (min) 26       MUM
# 39699  Metropolitian    (min) 39    RANCHI
# 40223  Metropolitian    (min) 40       MYS
# 41105  Metropolitian    (min) 48       VAD
# 41969  Metropolitian    (min) 15       KNP
# 42072  Metropolitian    (min) 28      INDO
# 42835  Metropolitian    (min) 19      BANG
# 45332          Urban    (min) 28       VAD
#
# [53 rows x 21 columns]

# %%
# No. of values with rating > 5

print(df[df['ratings'].astype(float) > 5].shape[0])
print(df[df['ratings'].astype(float) == 1].shape[0])
print(df[(df['ratings'].astype(float) == 1) & (df['age'].astype(float) == 15)].shape[0])
print(df[(df['ratings'].astype(float) == 1) | (df['age'].astype(float) == 15)].shape[0])
print(df[(df['ratings'].astype(float) > 5) & (df['age'].astype(float) == 50)].shape[0])
print(df[(df['ratings'].astype(float) > 5) | (df['age'].astype(float) == 50)].shape[0])
# Out:
# 53
# 38
# 38
# 38
# 53
# 53

# %% [markdown]
# ratings with 1 star with age value 15 and also 6 star and age value 50 are unique values and are possibly data errors as these values are unusual

# %% [markdown]
# **6 Star rating is possibly a data error**

# %%
# boxplot

sns.boxplot(df['ratings'].astype(float))
# Out:
# <Axes: ylabel='ratings'>

# %% [markdown]
# 1. **The Minors data have ratings as 1 which seems like an anomaly if we generally consider the ratings column distribution.**
#
# 2. **The rating of 6 is also one another anomaly in the data as maximum ratings are 5 and not more than that**
#     - Has to be investigated
#     - If data is problematic than fixing or removing is an option

# %%
# rows where the star rating is 6

six_star_data = df.loc[df['ratings'] == "6"]

len(six_star_data)
# Out:
# 53

# %%
six_star_data
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 3586    0x46d     BANGRES05DEL01   50       6           -12.970324
# 4714    0x493      HYDRES17DEL01   50       6           -17.451976
# 5169    0x4f2      JAPRES08DEL01   50       6           -26.910262
# 5362    0x430     BANGRES19DEL01   50       6            12.914264
# 5651   0xbef1      AGRRES13DEL02   50       6           -27.159795
# 10100         Snack   electric_scooter                    1      No
# 10737         Snack            scooter                    0      No
# 12297          Meal            scooter                    1      No
# 13257        Buffet   electric_scooter                    1      No
# 13652        Buffet         motorcycle                    0      No
# 14106          Meal            scooter                    0      No
# 14907        Drinks            bicycle                    0      No
# 14944          Meal         motorcycle                    1      No
# 16798        Drinks            scooter                    1      No
# 17145         Snack   electric_scooter                    0      No
# 17708        Drinks   electric_scooter                    1      No
# 18977        Buffet            scooter                    1      No
# 19382        Drinks            bicycle                    0      No
# 20269         Snack         motorcycle                    1      No
# 21320        Drinks   electric_scooter                    1      No
# 22416        Drinks            scooter                    0      No
# 23375        Buffet   electric_scooter                    0      No
# 24237          Meal         motorcycle                    0      No
# 24918        Buffet            scooter                    1      No
# 25285          Meal   electric_scooter                    0      No
# 26052          Meal   electric_scooter                    0      No
# 27221        Drinks   electric_scooter                    0      No
# 27399          Meal   electric_scooter                    1      No
# 28315        Drinks   electric_scooter                    0      No
# 28974          Meal   electric_scooter                    0      No
# 29535        Drinks   electric_scooter                    1      No
# 30579         Snack            bicycle                    2      No
# 30943          Meal            scooter                    1      No
# 31233        Drinks            scooter                    0      No
# 32326        Drinks            scooter                    0      No
# 33533         Snack            scooter                    1      No
# 34688        Drinks   electric_scooter                    1      No
# 38007         Snack   electric_scooter                    1      No
# 38020          Meal            scooter                    0      No
# 38561        Drinks   electric_scooter                    0      No
# 38649        Buffet   electric_scooter                    1      No
# 39699        Buffet            bicycle                    1      No
# 40223        Drinks   electric_scooter                    1      No
# 41105          Meal            scooter                    1     Yes
# 41969        Drinks            scooter                    1      No
# 42072        Buffet            scooter                    0      No
# 42835        Drinks   electric_scooter                    1      No
# 45332        Drinks   electric_scooter                    1      No
#
#             city_type time_taken city_name
# 3586           Urban    (min) 25      BANG
# 4714   Metropolitian    (min) 27       HYD
# 5169   Metropolitian    (min) 20       JAP
# 5362   Metropolitian    (min) 18      BANG
# 5651   Metropolitian    (min) 20       AGR
# 6394           Urban    (min) 20       JAP
# 7031   Metropolitian    (min) 14       MYS
# 7681   Metropolitian    (min) 22       VAD
# 9499           Urban    (min) 17      BANG
# 9535   Metropolitian    (min) 32    RANCHI
# 10100  Metropolitian    (min) 35       MYS
# 10737  Metropolitian    (min) 25       DEH
# 12297          Urban    (min) 22       SUR
# 13257          Urban    (min) 11     COIMB
# 13652  Metropolitian    (min) 28    RANCHI
# 14106          Urban    (min) 15       MYS
# 14907  Metropolitian    (min) 12      CHEN
# 14944          Urban    (min) 19       HYD
# 16798  Metropolitian    (min) 22    RANCHI
# 17145          Urban    (min) 14     COIMB
# 17708  Metropolitian    (min) 20      CHEN
# 18977  Metropolitian    (min) 17       BHP
# 19382  Metropolitian    (min) 30      INDO
# 20269          Urban    (min) 33       ALH
# 21320  Metropolitian    (min) 35       HYD
# 22416  Metropolitian    (min) 29       ALH
# 23375          Urban    (min) 19      BANG
# 24237  Metropolitian    (min) 17       SUR
# 24918  Metropolitian    (min) 41       KNP
# 25285  Metropolitian    (min) 16     COIMB
# 26052  Metropolitian    (min) 20    RANCHI
# 27221            NaN    (min) 17     COIMB
# 27399  Metropolitian    (min) 18       MUM
# 28315  Metropolitian    (min) 28      BANG
# 28974  Metropolitian    (min) 20      CHEN
# 29535  Metropolitian    (min) 15      BANG
# 30579  Metropolitian    (min) 39       BHP
# 30943          Urban    (min) 30       MUM
# 31233  Metropolitian    (min) 28       VAD
# 32326            NaN    (min) 17       KNP
# 33533  Metropolitian    (min) 28       KOL
# 34688          Urban    (min) 16       AGR
# 38007  Metropolitian    (min) 25       DEH
# 38020  Metropolitian    (min) 14      CHEN
# 38561  Metropolitian    (min) 36       VAD
# 38649          Urban    (min) 26       MUM
# 39699  Metropolitian    (min) 39    RANCHI
# 40223  Metropolitian    (min) 40       MYS
# 41105  Metropolitian    (min) 48       VAD
# 41969  Metropolitian    (min) 15       KNP
# 42072  Metropolitian    (min) 28      INDO
# 42835  Metropolitian    (min) 19      BANG
# 45332          Urban    (min) 28       VAD
#
# [53 rows x 21 columns]

# %%
six_star_index = six_star_data.index.tolist()

# %% [markdown]
# **Investigate further before action**
#
# Data removal seems logical at this stage.

# %% [markdown]
# ### Location Columns

# %%
location_columns = df.columns[4:8].tolist()

location_columns
# Out:
# ['restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude']

# %%
location_subset = df.loc[:,location_columns]
location_subset
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 0                22.745049             75.892471          22.765049
# 1                12.913041             77.683237          13.043041
# 2                12.914264             77.678400          12.924264
# 3                11.003669             76.976494          11.053669
# 4                12.972793             80.249982          13.012793
# ...                    ...                   ...                ...
# 45588            26.902328             75.794257          26.912328
# 45589             0.000000              0.000000           0.070000
# 45590            13.022394             80.242439          13.052394
# 45591            11.001753             76.986241          11.041753
# 45592            23.351058             85.325731          23.431058
#
#        delivery_longitude
# 0               75.912471
# 1               77.813237
# 2               77.688400
# 3               77.026494
# 4               80.289982
# ...                   ...
# 45588           75.804257
# 45589            0.070000
# 45590           80.272439
# 45591           77.026241
# 45592           85.405731
#
# [45593 rows x 4 columns]

# %% [markdown]
# **Valid values for lat and long**
#
#  > India lies to the north of the equator between `6° 44′` and `35° 30′` north latitude and `68° 7′` and `97° 25′` east longitude.

# %%
# statistical analysis

location_subset.describe()
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count         45593.000000          45593.000000       45593.000000
# mean             17.017729             70.231332          17.465186
# std               8.185109             22.883647           7.335122
# min             -30.905562            -88.366217           0.010000
# 25%              12.933284             73.170000          12.988453
# 50%              18.546947             75.898497          18.633934
# 75%              22.728163             78.044095          22.785049
# max              30.914057             88.433452          31.054057
#
#        delivery_longitude
# count        45593.000000
# mean            70.845702
# std             21.118812
# min              0.010000
# 25%             73.280000
# 50%             76.002574
# 75%             78.107044
# max             88.563452

# %%
# set the lower bound limits for the lat and long

lower_bound_lat = 6.44
lower_bound_long = 68.70

# %%
# rows of data where latitude and longitude values are below the bounds

df.loc[
    (df['restaurant_latitude'] < lower_bound_lat) |
    (df['restaurant_longitude'] < lower_bound_long) |
    (df['delivery_latitude'] < lower_bound_lat) |
    (df['delivery_longitude'] < lower_bound_long)
].sample(50)
# Out:
#             id           rider_id   age ratings  restaurant_latitude  \
# 33989   0x458     BANGRES20DEL01   NaN     NaN            -12.972161
# 19440  0x257a      VADRES08DEL01     26     4.8             0.000000
# 17994  0x39b0   RANCHIRES03DEL03     32     4.8             0.000000
# 14953  0xcc89     LUDHRES02DEL02     20     4.8             0.000000
# 7789   0xd713     AURGRES11DEL01     33     4.8             0.000000
# 10153   0x513      HYDRES07DEL01   NaN     NaN            -17.424114
# 40173  0xd2ff      AGRRES16DEL01     38     4.4             0.000000
# 13256  0x6c7a      VADRES16DEL02     32       4             0.000000
# 32523  0x5c79      VADRES02DEL01     22     4.7             0.000000
# 15347  0xc0e7      AGRRES11DEL01     34     4.6           -27.163303
# 9719   0xc95b      BHPRES12DEL01     34     4.1             0.000000
# 18101  0x4911      VADRES08DEL02     25     4.7             0.000000
# 16446  0x3aec   RANCHIRES12DEL01     36       4             0.000000
# 3768   0x3cf0   RANCHIRES14DEL01     28     4.8             0.000000
# 9842   0xdb14      BHPRES14DEL01     28     4.8             0.000000
# 43748  0xb5df   RANCHIRES02DEL02     33     4.1             0.000000
# 7148    0x54c      SURRES20DEL03   NaN     NaN            -21.152760
# 6167   0x7fa7   RANCHIRES12DEL01     38     4.7             0.000000
# 20984  0x7b90      VADRES16DEL01     30     4.7             0.000000
# 16420  0x30ee      VADRES02DEL03     30     4.8             0.000000
# 25871  0xc0e9     LUDHRES16DEL01     35     3.9           -30.895817
# 30116  0xd68d     LUDHRES02DEL01     20     4.8             0.000000
# 17349  0x55eb      VADRES04DEL01     24     4.6             0.000000
# 6503   0xd9d9     AURGRES02DEL03     24     4.9             0.000000
# 14436  0x5515      VADRES17DEL02     26       5             0.000000
# 32283   0x3f8    INDORES010DEL03   NaN     NaN            -22.750040
# 25753   0x510    COIMBRES02DEL03   NaN     NaN            -11.022477
# 23047  0xcabc      BHPRES02DEL03     34     4.1             0.000000
# 18030  0xca77      ALHRES09DEL03     23     4.9             0.000000
# 20800  0x1fb9      VADRES16DEL01     20     4.9             0.000000
# 10619   0x623   RANCHIRES04DEL02   NaN     NaN            -23.359033
# 34216  0xc0ff      KOCRES14DEL01     29       4           -10.027014
# 6242   0xce1e      DEHRES01DEL02     37     4.2             0.000000
# 41868  0x1b1d      VADRES07DEL03     22     4.7             0.000000
# 8134    0xc65      VADRES08DEL01     21     4.6             0.000000
# 37623  0xdcaf     AURGRES02DEL02     21     4.9             0.000000
# 31228  0xb4b8      VADRES15DEL01     35     4.9             0.000000
# 22119  0x9a45      VADRES12DEL02     30     3.7             0.000000
# 31768  0xcf68      GOARES05DEL01     31     4.6             0.000000
# 27018   0x548     VADRES010DEL01   NaN     NaN            -22.310329
# 43050  0xd31d      ALHRES11DEL01     32     4.9             0.000000
# 10153                 1        Drinks            scooter                    1
# 40173                 2        Buffet   electric_scooter                    2
# 13256                 2        Buffet            scooter                    1
# 32523                 2          Meal            scooter                    0
# 15347                 0        Drinks         motorcycle                 NaN
# 9719                  0        Buffet         motorcycle                    1
# 18101                 1         Snack            scooter                    0
# 16446                 0          Meal         motorcycle                    1
# 3768                  2        Buffet            scooter                    1
# 9842                  1         Snack            scooter                    0
# 43748                 2         Snack         motorcycle                    1
# 7148                  1          Meal         motorcycle                    1
# 6167                  1          Meal            scooter                    0
# 20984                 2         Snack         motorcycle                    0
# 16420                 1         Snack            scooter                 NaN
# 25871                 1        Buffet            scooter                    1
# 30116                 0        Drinks         motorcycle                    1
# 17349                 1          Meal            scooter                    1
# 6503                  0         Snack         motorcycle                    1
# 14436                 0        Buffet         motorcycle                    1
# 32283                 3         Snack            scooter                    1
# 25753                 2        Buffet            scooter                    0
# 23047                 2        Drinks            scooter                    1
# 18030                 1         Snack            scooter                    1
# 20800                 1        Drinks         motorcycle                    1
# 10619                 3         Snack            scooter                    1
# 34216                 1          Meal         motorcycle                    1
# 6242                  2          Meal            scooter                    2
# 41868                 1          Meal         motorcycle                    0
# 8134                  0        Drinks         motorcycle                    0
# 37623                 1        Drinks            scooter                    0
# 31228                 0          Meal         motorcycle                    1
# 22119                 2        Drinks   electric_scooter                    1
# 31768                 2         Snack         motorcycle                    0
# 27018                 2         Snack            scooter                    1
# 43050                 1          Meal         motorcycle                    0
# 24534                 1          Meal            scooter                    1
# 15650                 2          Meal            scooter                    0
# 36748                 2         Snack            scooter                    0
# 29391                 1         Snack         motorcycle                    1
# 2615                  2        Drinks            scooter                    0
# 35968                 0          Meal         motorcycle                    0
# 15768                 2        Buffet            scooter                    0
# 40927                 1          Meal         motorcycle                    2
# 42791                 1        Buffet            scooter                    0
#
#       festival       city_type time_taken city_name
# 33989      No           Urban    (min) 25      BANG
# 19440      No   Metropolitian    (min) 28       VAD
# 17994      No   Metropolitian    (min) 12    RANCHI
# 14953      No   Metropolitian    (min) 18      LUDH
# 7789       No   Metropolitian    (min) 28      AURG
# 10153      No           Urban    (min) 17       HYD
# 40173      No   Metropolitian    (min) 38       AGR
# 13256      No   Metropolitian    (min) 34       VAD
# 32523      No   Metropolitian    (min) 17       VAD
# 15347      No   Metropolitian    (min) 28       AGR
# 9719       No             NaN    (min) 37       BHP
# 18101      No   Metropolitian    (min) 15       VAD
# 16446      No           Urban    (min) 39    RANCHI
# 3768       No           Urban    (min) 17    RANCHI
# 9842       No           Urban    (min) 11       BHP
# 43748      No   Metropolitian    (min) 31    RANCHI
# 7148       No   Metropolitian    (min) 18       SUR
# 6167       No           Urban    (min) 15    RANCHI
# 20984      No           Urban    (min) 18       VAD
# 16420      No           Urban    (min) 23       VAD
# 25871      No   Metropolitian    (min) 32      LUDH
# 30116      No   Metropolitian    (min) 18      LUDH
# 17349      No   Metropolitian    (min) 17       VAD
# 6503       No   Metropolitian    (min) 21      AURG
# 14436      No   Metropolitian    (min) 21       VAD
# 32283      No   Metropolitian    (min) 26      INDO
# 25753      No           Urban    (min) 20     COIMB
# 23047      No   Metropolitian    (min) 32       BHP
# 18030      No   Metropolitian    (min) 25       ALH
# 20800      No   Metropolitian    (min) 17       VAD
# 10619      No           Urban    (min) 22    RANCHI
# 34216      No   Metropolitian    (min) 31       KOC
# 6242       No   Metropolitian    (min) 42       DEH
# 41868      No           Urban    (min) 10       VAD
# 8134       No   Metropolitian    (min) 19       VAD
# 37623      No           Urban    (min) 11      AURG
# 31228      No   Metropolitian    (min) 38       VAD
# 22119      No   Metropolitian    (min) 44       VAD
# 31768      No   Metropolitian    (min) 48       GOA
# 27018      No   Metropolitian    (min) 24       VAD
# 43050      No   Metropolitian    (min) 30       ALH
# 24534      No           Urban    (min) 22      PUNE
# 15650      No   Metropolitian    (min) 41       VAD
# 36748      No   Metropolitian    (min) 18       VAD
# 29391      No           Urban    (min) 16       MYS
# 2615       No   Metropolitian    (min) 24    RANCHI
# 35968      No   Metropolitian    (min) 18       VAD
# 15768      No   Metropolitian    (min) 30       BHP
# 40927      No   Metropolitian    (min) 34       VAD
# 42791      No   Metropolitian    (min) 25       VAD
#
# [50 rows x 21 columns]

# %%
# number of rows in data where lat long are erroneous

location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].shape[0]
# Out:
# 4071

# %% [markdown]
# **There are 4071 rows in the data where the lat long columns are messy**

# %%
# statistical summary of problematic rows where lat long is below the country's geographical limits

location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].describe()
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count          4071.000000           4071.000000        4071.000000
# mean             -2.149416              2.068601           2.212538
# std               6.537913             25.270676           6.538283
# min             -30.905562            -88.366217           0.010000
# 25%               0.000000              0.000000           0.040000
# 50%               0.000000              0.000000           0.070000
# 75%               0.000000              0.000000           0.110000
# max               0.000000             88.433452          31.045562
#
#        delivery_longitude
# count         4071.000000
# mean             8.299885
# std             23.980011
# min              0.010000
# 25%              0.040000
# 50%              0.070000
# 75%              0.110000
# max             88.523452

# %%
# boxplots for all the anomalies

location_subset.loc[
    (location_subset['restaurant_latitude'] < lower_bound_lat) |
    (location_subset['restaurant_longitude'] < lower_bound_long) |
    (location_subset['delivery_latitude'] < lower_bound_lat) |
    (location_subset['delivery_longitude'] < lower_bound_long)
].plot(kind="box")

plt.xticks(rotation=45)
# Out:
# (array([1, 2, 3, 4]),
#  [Text(1, 0, 'restaurant_latitude'),
#   Text(2, 0, 'restaurant_longitude'),
#   Text(3, 0, 'delivery_latitude'),
#   Text(4, 0, 'delivery_longitude')])

# %% [markdown]
# **Negative Values are correct just we have to take absolute**
#
# **While calculating the distances we can assign null values to these erroneous data points and then impute the values using advanced imputation techniques**

# %%
# taking the absolute values

(
    location_subset.abs()
    .plot(kind="box")
)

ax = plt.gca()

ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(1, 0, 'restaurant_latitude'),
#  Text(2, 0, 'restaurant_longitude'),
#  Text(3, 0, 'delivery_latitude'),
#  Text(4, 0, 'delivery_longitude')]

# %%
# number of rows after taking absolute values

(
    location_subset.abs()
    .loc[lambda df_:
        (df_['restaurant_latitude'] < lower_bound_lat) |
        (df_['restaurant_longitude'] < lower_bound_long) |
        (df_['delivery_latitude'] < lower_bound_lat) |
        (df_['delivery_longitude'] < lower_bound_long)]
    .shape[0]

)
# Out:
# 3640

# %% [markdown]
# **`3640` rows in the data that have messy lat long values**

# %%
# lat long values less than 1

location_subset.abs().loc[lambda df_:
                        (df_['restaurant_latitude'] < 1) |
                        (df_['restaurant_longitude'] < 1) |
                        (df_['delivery_latitude'] < 1) |
                        (df_['delivery_longitude'] < 1)]
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# 33                     0.0                   0.0               0.11
# 52                     0.0                   0.0               0.03
# 57                     0.0                   0.0               0.08
# 59                     0.0                   0.0               0.06
# 67                     0.0                   0.0               0.02
# ...                    ...                   ...                ...
# 45569                  0.0                   0.0               0.07
# 45576                  0.0                   0.0               0.13
# 45577                  0.0                   0.0               0.09
# 45579                  0.0                   0.0               0.05
# 45589                  0.0                   0.0               0.07
#
#        delivery_longitude
# 33                   0.11
# 52                   0.03
# 57                   0.08
# 59                   0.06
# 67                   0.02
# ...                   ...
# 45569                0.07
# 45576                0.13
# 45577                0.09
# 45579                0.05
# 45589                0.07
#
# [3640 rows x 4 columns]

# %% [markdown]
# **All the messy lat long values are less than 1**

# %%
def clean_lat_long(data: pd.DataFrame, threshold=1):
    location_columns = location_subset.columns.tolist()

    return (
        data
        .assign(**{
            col: (
                np.where(data[col] < threshold, np.nan, data[col].values)
            )
            for col in location_columns
        })
    )

# %%
clean_lat_long(df).isna().sum().sum()
# Out:
# np.int64(15153)

# %% [markdown]
# ### Order Date

# %%
# check for missing values

df['order_date'].isna().sum()
# Out:
# np.int64(0)

# %%
# unique values in order date

df['order_date'].unique()
# Out:
# array(['19-03-2022', '25-03-2022', '05-04-2022', '26-03-2022',
#        '11-03-2022', '04-03-2022', '14-03-2022', '20-03-2022',
#        '12-02-2022', '13-02-2022', '14-02-2022', '02-04-2022',
#        '01-03-2022', '16-03-2022', '15-02-2022', '10-03-2022',
#        '27-03-2022', '12-03-2022', '01-04-2022', '05-03-2022',
#        '11-02-2022', '08-03-2022', '03-04-2022', '30-03-2022',
#        '28-03-2022', '18-03-2022', '06-04-2022', '04-04-2022',
#        '24-03-2022', '09-03-2022', '02-03-2022', '13-03-2022',
#        '29-03-2022', '31-03-2022', '17-03-2022', '07-03-2022',
#        '15-03-2022', '16-02-2022', '03-03-2022', '18-02-2022',
#        '23-03-2022', '17-02-2022', '06-03-2022', '21-03-2022'],
#       dtype=object)

# %%
# date range

order_date = pd.to_datetime(df['order_date'],dayfirst=True)

order_date.max() - order_date.min()
# Out:
# Timedelta('54 days 00:00:00')

# %%
# min and maximum dates

order_date.agg(["min","max"]).set_axis(["start","end"],axis=0)
# Out:
# start   2022-02-11
# end     2022-04-06
# Name: order_date, dtype: datetime64[ns]

# %%
# extract day, day name, month and year

def extract_datetime_features(ser):
    date_col = pd.to_datetime(ser,dayfirst=True)

    return (
        pd.DataFrame(
            {
                "day": date_col.dt.day,
                "month": date_col.dt.month,
                "year": date_col.dt.year,
                "day_of_week": date_col.dt.day_name(),
                "is_weekend": date_col.dt.day_name().isin(["Saturday","Sunday"]).astype(int)
            }
        ))

# %%
extract_datetime_features(df['order_date'])
# Out:
#        day  month  year day_of_week  is_weekend
# 0       19      3  2022    Saturday           1
# 1       25      3  2022      Friday           0
# 2       19      3  2022    Saturday           1
# 3        5      4  2022     Tuesday           0
# 4       26      3  2022    Saturday           1
# ...    ...    ...   ...         ...         ...
# 45588   24      3  2022    Thursday           0
# 45589   16      2  2022   Wednesday           0
# 45590   11      3  2022      Friday           0
# 45591    7      3  2022      Monday           0
# 45592    2      3  2022   Wednesday           0
#
# [45593 rows x 5 columns]

# %% [markdown]
# ### Order time and Order picked time

# %%
# extract hour info from data

order_time_hr = pd.to_datetime(df.replace("NaN ",np.nan)['order_time'],format='mixed').dt.hour

order_time_hr
# Out:
# 0        11.0
# 1        19.0
# 2         8.0
# 3        18.0
# 4        13.0
#          ...
# 45588    11.0
# 45589    19.0
# 45590    23.0
# 45591    13.0
# 45592    17.0
# Name: order_time, Length: 45593, dtype: float64

# %%
def time_of_day(ser):
    time_col = pd.to_datetime(ser,format='mixed').dt.hour

    return(
        np.select(condlist=[(ser.between(6,12,inclusive='left')),
                            (ser.between(12,17,inclusive='left')),
                            (ser.between(17,20,inclusive='left')),
                            (ser.between(20,24,inclusive='left'))],
                  choicelist=["morning","afternoon","evening","night"],
                  default="after_midnight")
    )

# %%
time_subset = df.loc[:,["order_time","order_picked_time"]]
time_subset
# Out:
#       order_time order_picked_time
# 0       11:30:00          11:45:00
# 1       19:45:00          19:50:00
# 2       08:30:00          08:45:00
# 3       18:00:00          18:10:00
# 4       13:30:00          13:45:00
# ...          ...               ...
# 45588   11:35:00          11:45:00
# 45589   19:55:00          20:10:00
# 45590   23:50:00          00:05:00
# 45591   13:35:00          13:40:00
# 45592   17:10:00          17:15:00
#
# [45593 rows x 2 columns]

# %%
(
    time_subset
    .dtypes
)
# Out:
# order_time           object
# order_picked_time    object
# dtype: object

# %%
time_subset.columns.tolist()
# Out:
# ['order_time', 'order_picked_time']

# %%
# calculate the pickup time

(
    time_subset
    .assign(**{
        col: pd.to_datetime(time_subset[col].replace("NaN ",np.nan).dropna(),format="mixed")
        for col in time_subset.columns.tolist()}
    )
    .assign(
        pickup_time = lambda x: (x['order_picked_time'] - x['order_time']).dt.seconds / 60,
        order_time_hour = lambda x: x['order_time'].dt.hour,
        order_time_of_day = lambda x: x['order_time_hour'].pipe(time_of_day)
    )
    .drop(columns=["order_time","order_picked_time"])
)
# Out:
#        pickup_time  order_time_hour order_time_of_day
# 0             15.0             11.0           morning
# 1              5.0             19.0           evening
# 2             15.0              8.0           morning
# 3             10.0             18.0           evening
# 4             15.0             13.0         afternoon
# ...            ...              ...               ...
# 45588         10.0             11.0           morning
# 45589         15.0             19.0           evening
# 45590         15.0             23.0             night
# 45591          5.0             13.0         afternoon
# 45592          5.0             17.0           evening
#
# [45593 rows x 3 columns]

# %% [markdown]
# ### Weather

# %%
# value counts

df['weather'].value_counts()
# Out:
# weather
# conditions Fog           7654
# conditions Stormy        7586
# conditions Cloudy        7536
# conditions Sandstorms    7495
# conditions Windy         7422
# conditions Sunny         7284
# conditions NaN            616
# Name: count, dtype: int64

# %%
# unique values
df['weather'].unique()
# Out:
# array(['conditions Sunny', 'conditions Stormy', 'conditions Sandstorms',
#        'conditions Cloudy', 'conditions Fog', 'conditions Windy',
#        'conditions NaN'], dtype=object)

# %%
# remove conditions from values

(
    df['weather']
    .str.replace("conditions ","")
    .unique()
)
# Out:
# array(['Sunny', 'Stormy', 'Sandstorms', 'Cloudy', 'Fog', 'Windy', 'NaN'],
#       dtype=object)

# %% [markdown]
# ### Traffic

# %%
# value counts

df['traffic'].value_counts()
# Out:
# traffic
# Low        15477
# Jam        14143
# Medium     10947
# High        4425
# NaN          601
# Name: count, dtype: int64

# %%
# unique values
df['traffic'].unique()
# Out:
# array(['High ', 'Jam ', 'Low ', 'Medium ', 'NaN '], dtype=object)

# %%
(
    df['traffic']
    .replace("NaN ",np.nan)
    .str.strip()
    .str.lower()
    .unique()
)
# Out:
# array(['high', 'jam', 'low', 'medium', nan], dtype=object)

# %% [markdown]
# ### Vehicle Condition

# %%
# unique values in column

np.sort(df['vehicle_condition'].unique())
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ### Type of order

# %%
# value counts

df['type_of_order'].value_counts()
# Out:
# type_of_order
# Snack      11533
# Meal       11458
# Drinks     11322
# Buffet     11280
# Name: count, dtype: int64

# %%
# unique values
df['type_of_order'].unique()
# Out:
# array(['Snack ', 'Drinks ', 'Buffet ', 'Meal '], dtype=object)

# %%
(
    df['type_of_order']
    .str.strip()
    .str.lower()
    .unique()
)
# Out:
# array(['snack', 'drinks', 'buffet', 'meal'], dtype=object)

# %% [markdown]
# ### Type of vehicle

# %%
# value counts

df['type_of_vehicle'].value_counts()
# Out:
# type_of_vehicle
# motorcycle           26435
# scooter              15276
# electric_scooter      3814
# bicycle                 68
# Name: count, dtype: int64

# %%
df.groupby(['type_of_vehicle'])['vehicle_condition'].value_counts().sort_values(ascending=False).sort_index(ascending=True)
# Out:
# type_of_vehicle    vehicle_condition
# bicycle            3                       68
# electric_scooter   2                     3626
#                    3                      188
# motorcycle         0                    15009
#                    1                     7583
#                    2                     3753
#                    3                       90
# scooter            1                     7447
#                    2                     7655
#                    3                      174
# Name: count, dtype: int64

# %%
# unique values
df['type_of_vehicle'].unique()
# Out:
# array(['motorcycle ', 'scooter ', 'electric_scooter ', 'bicycle '],
#       dtype=object)

# %%
(
    df['type_of_vehicle']
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['motorcycle', 'scooter', 'electric_scooter', 'bicycle'],
#       dtype=object)

# %% [markdown]
# ### Multiple Deliveries

# %%
# datatype of multiple deliveries column

df['multiple_deliveries'].dtype
# Out:
# dtype('O')

# %%
# unique values in column

np.sort(df['multiple_deliveries'].unique())
# Out:
# array(['0', '1', '2', '3', 'NaN '], dtype=object)

# %%
# make the column as integer

(
    df['multiple_deliveries']
    .replace("NaN ",np.nan)
    .astype(float)
    .unique()
)
# Out:
# array([ 0.,  1.,  3., nan,  2.])

# %% [markdown]
# ### Festival

# %%
# unique values in column

df['festival'].unique()
# Out:
# array(['No ', 'Yes ', 'NaN '], dtype=object)

# %%
(
    df['festival']
    .replace("NaN ",np.nan)
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['no', 'yes', nan], dtype=object)

# %% [markdown]
# ### City type

# %%
# unique values in city type

df['city_type'].unique()
# Out:
# array(['Urban ', 'Metropolitian ', 'Semi-Urban ', 'NaN '], dtype=object)

# %%
(
    df['city_type']
    .replace("NaN ",np.nan)
    .str.rstrip()
    .str.lower()
    .unique()
)
# Out:
# array(['urban', 'metropolitian', 'semi-urban', nan], dtype=object)

# %% [markdown]
# ### Time Taken

# %%
# datatype of time taken

df['time_taken'].dtype
# Out:
# dtype('O')

# %%
(
    df['time_taken']
    .str.replace("(min) ","")
    .astype(int)
)
# Out:
# 0        24
# 1        33
# 2        26
# 3        21
# 4        30
#          ..
# 45588    32
# 45589    36
# 45590    16
# 45591    26
# 45592    36
# Name: time_taken, Length: 45593, dtype: int64

# %% [markdown]
# ## Perform Cleaning and Feature Building

# %%
df.columns
# Out:
# Index(['id', 'rider_id', 'age', 'ratings', 'restaurant_latitude',
#        'restaurant_longitude', 'delivery_latitude', 'delivery_longitude',
#        'order_date', 'order_time', 'order_picked_time', 'weather', 'traffic',
#        'vehicle_condition', 'type_of_order', 'type_of_vehicle',
#        'multiple_deliveries', 'festival', 'city_type', 'time_taken',
#        'city_name'],
#       dtype='object')

# %%
def data_cleaning(data: pd.DataFrame):

    return (
        data
        .drop(columns="id")
        .drop(index=minor_index)                                                # Minor riders in data dropped
        .drop(index=six_star_index)                                             # six star rated drivers dropped
        .replace("NaN ",np.nan)                                                 # missing values in the data
        .assign(
            # city column out of rider id
            city_name = lambda x: x['rider_id'].str.split("RES").str.get(0),
            # convert age to float
            age = lambda x: x['age'].astype(float),
            # convert ratings to float
            ratings = lambda x: x['ratings'].astype(float),
            # absolute values for location based columns
            restaurant_latitude = lambda x: x['restaurant_latitude'].abs(),
            restaurant_longitude = lambda x: x['restaurant_longitude'].abs(),
            delivery_latitude = lambda x: x['delivery_latitude'].abs(),
            delivery_longitude = lambda x: x['delivery_longitude'].abs(),
            # order date to datetime and feature extraction
            order_date = lambda x: pd.to_datetime(x['order_date'],
                                                  dayfirst=True),
            order_day = lambda x: x['order_date'].dt.day,
            order_month = lambda x: x['order_date'].dt.month,
            order_day_of_week = lambda x: x['order_date'].dt.day_name().str.lower(),
            is_weekend = lambda x: (x['order_date']
                                    .dt.day_name()
                                    .isin(["Saturday","Sunday"])
                                    .astype(int)),
            # time based columns
            order_time = lambda x: pd.to_datetime(x['order_time'],
                                                  format='mixed'),
            order_picked_time = lambda x: pd.to_datetime(x['order_picked_time'],
                                                         format='mixed'),
            # time taken to pick order
            pickup_time_minutes = lambda x: (
                                            (x['order_picked_time'] - x['order_time'])
                                            .dt.seconds / 60
                                            ),
            # hour in which order was placed
            order_time_hour = lambda x: x['order_time'].dt.hour,
            # time of the day when order was placed
            order_time_of_day = lambda x: (
                                x['order_time_hour'].pipe(time_of_day)),
            # categorical columns
            weather = lambda x: (
                                x['weather']
                                .str.replace("conditions ","")
                                .str.lower()
                                .replace("nan",np.nan)),
            traffic = lambda x: x["traffic"].str.rstrip().str.lower(),
            type_of_order = lambda x: x['type_of_order'].str.rstrip().str.lower(),
            type_of_vehicle = lambda x: x['type_of_vehicle'].str.rstrip().str.lower(),
            festival = lambda x: x['festival'].str.rstrip().str.lower(),
            city_type = lambda x: x['city_type'].str.rstrip().str.lower(),
            # multiple deliveries column
            multiple_deliveries = lambda x: x['multiple_deliveries'].astype(float),
            # target column modifications
            time_taken = lambda x: (x['time_taken']
                                    .str.replace("(min) ","")
                                    .astype(int)))
        .drop(columns=["order_time","order_picked_time"])
    )

# %%
df
# Out:
#             id           rider_id age ratings  restaurant_latitude  \
# 0      0x4607     INDORES13DEL02   37     4.9            22.745049
# 1      0xb379     BANGRES18DEL02   34     4.5            12.913041
# 2      0x5d6d     BANGRES19DEL01   23     4.4            12.914264
# 3      0x7a6a    COIMBRES13DEL02   38     4.7            11.003669
# 4      0x70a2     CHENRES12DEL01   32     4.6            12.972793
# ...        ...                ...  ..     ...                  ...
# 45588  0x7c09      JAPRES04DEL01   30     4.8            26.902328
# 45589  0xd641      AGRRES16DEL01   21     4.6             0.000000
# 45590  0x4f8d     CHENRES08DEL03   30     4.9            13.022394
# 45591  0x5eee    COIMBRES11DEL01   20     4.7            11.001753
# 45592  0x5fb2   RANCHIRES09DEL02   23     4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45588             75.794257          26.912328           75.804257
# 45589              0.000000           0.070000            0.070000
# 45590             80.242439          13.052394           80.272439
# 45591             76.986241          11.041753           77.026241
# 45592             85.325731          23.431058           85.405731
#
#        order_date order_time  ...                weather  traffic  \
# 0      19-03-2022   11:30:00  ...       conditions Sunny    High
# 1      25-03-2022   19:45:00  ...      conditions Stormy     Jam
# 2      19-03-2022   08:30:00  ...  conditions Sandstorms     Low
# 3      05-04-2022   18:00:00  ...       conditions Sunny  Medium
# 4      26-03-2022   13:30:00  ...      conditions Cloudy    High
# ...           ...        ...  ...                    ...      ...
# 45588  24-03-2022   11:35:00  ...       conditions Windy    High
# 45589  16-02-2022   19:55:00  ...       conditions Windy     Jam
# 45590  11-03-2022   23:50:00  ...      conditions Cloudy     Low
# 45591  07-03-2022   13:35:00  ...      conditions Cloudy    High
# 45592  02-03-2022   17:10:00  ...         conditions Fog  Medium
#
#       vehicle_condition  type_of_order type_of_vehicle multiple_deliveries  \
# 0                     2         Snack      motorcycle                    0
# 1                     2         Snack         scooter                    1
# 2                     0        Drinks      motorcycle                    1
# 3                     0        Buffet      motorcycle                    1
# 4                     1         Snack         scooter                    1
# ...                 ...            ...             ...                 ...
# 45588                 1          Meal      motorcycle                    0
# 45589                 0        Buffet      motorcycle                    1
# 45590                 1        Drinks         scooter                    0
# 45591                 0         Snack      motorcycle                    1
# 45592                 2         Snack         scooter                    1
#
#       festival       city_type time_taken city_name
# 0          No           Urban    (min) 24      INDO
# 1          No   Metropolitian    (min) 33      BANG
# 2          No           Urban    (min) 26      BANG
# 3          No   Metropolitian    (min) 21     COIMB
# 4          No   Metropolitian    (min) 30      CHEN
# ...        ...             ...        ...       ...
# 45588      No   Metropolitian    (min) 32       JAP
# 45589      No   Metropolitian    (min) 36       AGR
# 45590      No   Metropolitian    (min) 16      CHEN
# 45591      No   Metropolitian    (min) 26     COIMB
# 45592      No   Metropolitian    (min) 36    RANCHI
#
# [45593 rows x 21 columns]

# %%
data_cleaning(df)
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45588     JAPRES04DEL01   30.0      4.8            26.902328
# 45589     AGRRES16DEL01   21.0      4.6             0.000000
# 45590    CHENRES08DEL03   30.0      4.9            13.022394
# 45591   COIMBRES11DEL01   20.0      4.7            11.001753
# 45592  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude order_date  \
# 0                 75.892471          22.765049           75.912471 2022-03-19
# 1                 77.683237          13.043041           77.813237 2022-03-25
# 2                 77.678400          12.924264           77.688400 2022-03-19
# 3                 76.976494          11.053669           77.026494 2022-04-05
# 4                 80.249982          13.012793           80.289982 2022-03-26
# ...                     ...                ...                 ...        ...
# 45588             75.794257          26.912328           75.804257 2022-03-24
# 45589              0.000000           0.070000            0.070000 2022-02-16
# 45590             80.242439          13.052394           80.272439 2022-03-11
# 45591             76.986241          11.041753           77.026241 2022-03-07
# 45592             85.325731          23.431058           85.405731 2022-03-02
#
#           weather traffic  ...      city_type time_taken city_name  order_day  \
# 0           sunny    high  ...          urban         24      INDO         19
# 1          stormy     jam  ...  metropolitian         33      BANG         25
# 2      sandstorms     low  ...          urban         26      BANG         19
# 3           sunny  medium  ...  metropolitian         21     COIMB          5
# 4          cloudy    high  ...  metropolitian         30      CHEN         26
# ...           ...     ...  ...            ...        ...       ...        ...
# 45588       windy    high  ...  metropolitian         32       JAP         24
# 45589       windy     jam  ...  metropolitian         36       AGR         16
# 45590      cloudy     low  ...  metropolitian         16      CHEN         11
# 45591      cloudy    high  ...  metropolitian         26     COIMB          7
# 45592         fog  medium  ...  metropolitian         36    RANCHI          2
#
#       order_month order_day_of_week  is_weekend pickup_time_minutes  \
# 0               3          saturday           1                15.0
# 1               3            friday           0                 5.0
# 2               3          saturday           1                15.0
# 3               4           tuesday           0                10.0
# 4               3          saturday           1                15.0
# ...           ...               ...         ...                 ...
# 45588           3          thursday           0                10.0
# 45589           2         wednesday           0                15.0
# 45590           3            friday           0                15.0
# 45591           3            monday           0                 5.0
# 45592           3         wednesday           0                 5.0
#
#        order_time_hour  order_time_of_day
# 0                 11.0            morning
# 1                 19.0            evening
# 2                  8.0            morning
# 3                 18.0            evening
# 4                 13.0          afternoon
# ...                ...                ...
# 45588             11.0            morning
# 45589             19.0            evening
# 45590             23.0              night
# 45591             13.0          afternoon
# 45592             17.0            evening
#
# [45502 rows x 25 columns]

# %%
location_subset.columns.tolist()
# Out:
# ['restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude']

# %%
def calculate_haversine_distance(df):
    location_columns = location_subset.columns.tolist()
    lat1 = df[location_columns[0]]
    lon1 = df[location_columns[1]]
    lat2 = df[location_columns[2]]
    lon2 = df[location_columns[3]]

    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    distance = 6371 * c

    return (
        df.assign(
            distance = distance)
    )

# %%
# add more data cleaning steps

cleaned_data = (
                df.pipe(data_cleaning)
                .pipe(clean_lat_long)
                .pipe(calculate_haversine_distance)
                )

cleaned_data
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45588     JAPRES04DEL01   30.0      4.8            26.902328
# 45589     AGRRES16DEL01   21.0      4.6                  NaN
# 45590    CHENRES08DEL03   30.0      4.9            13.022394
# 45591   COIMBRES11DEL01   20.0      4.7            11.001753
# 45592  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude order_date  \
# 0                 75.892471          22.765049           75.912471 2022-03-19
# 1                 77.683237          13.043041           77.813237 2022-03-25
# 2                 77.678400          12.924264           77.688400 2022-03-19
# 3                 76.976494          11.053669           77.026494 2022-04-05
# 4                 80.249982          13.012793           80.289982 2022-03-26
# ...                     ...                ...                 ...        ...
# 45588             75.794257          26.912328           75.804257 2022-03-24
# 45589                   NaN                NaN                 NaN 2022-02-16
# 45590             80.242439          13.052394           80.272439 2022-03-11
# 45591             76.986241          11.041753           77.026241 2022-03-07
# 45592             85.325731          23.431058           85.405731 2022-03-02
#
#           weather traffic  ...  time_taken city_name order_day  order_month  \
# 0           sunny    high  ...          24      INDO        19            3
# 1          stormy     jam  ...          33      BANG        25            3
# 2      sandstorms     low  ...          26      BANG        19            3
# 3           sunny  medium  ...          21     COIMB         5            4
# 4          cloudy    high  ...          30      CHEN        26            3
# ...           ...     ...  ...         ...       ...       ...          ...
# 45588       windy    high  ...          32       JAP        24            3
# 45589       windy     jam  ...          36       AGR        16            2
# 45590      cloudy     low  ...          16      CHEN        11            3
# 45591      cloudy    high  ...          26     COIMB         7            3
# 45592         fog  medium  ...          36    RANCHI         2            3
#
#       order_day_of_week is_weekend  pickup_time_minutes order_time_hour  \
# 0              saturday          1                 15.0            11.0
# 1                friday          0                  5.0            19.0
# 2              saturday          1                 15.0             8.0
# 3               tuesday          0                 10.0            18.0
# 4              saturday          1                 15.0            13.0
# ...                 ...        ...                  ...             ...
# 45588          thursday          0                 10.0            11.0
# 45589         wednesday          0                 15.0            19.0
# 45590            friday          0                 15.0            23.0
# 45591            monday          0                  5.0            13.0
# 45592         wednesday          0                  5.0            17.0
#
#        order_time_of_day   distance
# 0                morning   3.025149
# 1                evening  20.183530
# 2                morning   1.552758
# 3                evening   7.790401
# 4              afternoon   6.210138
# ...                  ...        ...
# 45588            morning   1.489846
# 45589            evening        NaN
# 45590              night   4.657195
# 45591          afternoon   6.232393
# 45592            evening  12.074396
#
# [45502 rows x 26 columns]

# %% [markdown]
# ## Validate Data Cleaning

# %%
# age column

cleaned_data['age'].agg(["min","max"])
# Out:
# min    20.0
# max    39.0
# Name: age, dtype: float64

# %%
# ratings column

cleaned_data['ratings'].agg(["min","max"])
# Out:
# min    2.5
# max    5.0
# Name: ratings, dtype: float64

# %%
# location columns

cleaned_data[location_columns].plot(kind="box")

plt.xticks(rotation=45)

display(cleaned_data[location_columns].describe())
# Out:
#        restaurant_latitude  restaurant_longitude  delivery_latitude  \
# count         41872.000000          41872.000000       41872.000000
# mean             18.913696             76.921664          18.977356
# std               5.467265              3.503107           5.469056
# min               9.957144             72.768726           9.967144
# 25%              12.986047             73.897902          13.065996
# 50%              19.065838             76.618203          19.124049
# 75%              22.751234             78.368855          22.820040
# max              30.914057             88.433452          31.054057
#
#        delivery_longitude
# count        41872.000000
# mean            76.985325
# std              3.503260
# min             72.778726
# 25%             73.940327
# 50%             76.662620
# 75%             78.405467
# max             88.563452

# %%
# values in categorical columns

cat_cols = cleaned_data.select_dtypes(include="object").columns.tolist()

for col in cat_cols:
    print(f"For {col} unique values are: {cleaned_data[col].unique()}",end="\n\n\n\n")
# Out:
# For rider_id unique values are: ['INDORES13DEL02 ' 'BANGRES18DEL02 ' 'BANGRES19DEL01 ' ...
#  'KOCRES04DEL01 ' 'BHPRES06DEL03 ' 'GOARES03DEL03 ']
#
#
#
# For weather unique values are: ['sunny' 'stormy' 'sandstorms' 'cloudy' 'fog' 'windy' nan]
#
#
#
# For traffic unique values are: ['high' 'jam' 'low' 'medium' nan]
#
#
#
# For type_of_order unique values are: ['snack' 'drinks' 'buffet' 'meal']
#
#
#
# For type_of_vehicle unique values are: ['motorcycle' 'scooter' 'electric_scooter' 'bicycle']
#
#
#
# For festival unique values are: ['no' 'yes' nan]
#
#
#
# For city_type unique values are: ['urban' 'metropolitian' 'semi-urban' nan]
#
#
#
# For city_name unique values are: ['INDO' 'BANG' 'COIMB' 'CHEN' 'HYD' 'RANCHI' 'MYS' 'DEH' 'KOC' 'PUNE'
#  'LUDH' 'KNP' 'MUM' 'KOL' 'JAP' 'SUR' 'GOA' 'AURG' 'AGR' 'VAD' 'ALH' 'BHP']
#
#
#
# For order_day_of_week unique values are: ['saturday' 'friday' 'tuesday' 'monday' 'sunday' 'wednesday' 'thursday']
#
#
#
# For order_time_of_day unique values are: ['morning' 'evening' 'afternoon' 'night' 'after_midnight']

# %%
# bar plot of missing values

msno.bar(cleaned_data)
# Out:
# <Axes: >

# %%
# matrix of missing values

msno.matrix(cleaned_data)
# Out:
# <Axes: >

# %%
# correlation chart of missing values
fig, ax = plt.subplots(figsize=(15, 6)) # Adjust the figure size as needed
msno.heatmap(cleaned_data, ax=ax, fontsize=8) # Add fontsize argument
# Out:
# <Axes: >

# %% [markdown]
# # Save Cleaned Data

# %%
# save the cleaned data

cleaned_data.to_csv("cleaned_data.csv",index=False)

# %%
# load the cleaned data

cleaned_data_load = pd.read_csv("cleaned_data.csv")

# %%
# data types of cleaned data

cleaned_data_load.dtypes
# Out:
# rider_id                 object
# age                     float64
# ratings                 float64
# restaurant_latitude     float64
# restaurant_longitude    float64
# delivery_latitude       float64
# delivery_longitude      float64
# order_date               object
# weather                  object
# traffic                  object
# vehicle_condition         int64
# type_of_order            object
# type_of_vehicle          object
# multiple_deliveries     float64
# festival                 object
# city_type                object
# time_taken                int64
# city_name                object
# order_day                 int64
# order_month               int64
# order_day_of_week        object
# is_weekend                int64
# pickup_time_minutes     float64
# order_time_hour         float64
# order_time_of_day        object
# distance                float64
# dtype: object

# %%
cleaned_data_load
# Out:
#                 rider_id   age  ratings  restaurant_latitude  \
# 0        INDORES13DEL02   37.0      4.9            22.745049
# 1        BANGRES18DEL02   34.0      4.5            12.913041
# 2        BANGRES19DEL01   23.0      4.4            12.914264
# 3       COIMBRES13DEL02   38.0      4.7            11.003669
# 4        CHENRES12DEL01   32.0      4.6            12.972793
# ...                  ...   ...      ...                  ...
# 45497     JAPRES04DEL01   30.0      4.8            26.902328
# 45498     AGRRES16DEL01   21.0      4.6                  NaN
# 45499    CHENRES08DEL03   30.0      4.9            13.022394
# 45500   COIMBRES11DEL01   20.0      4.7            11.001753
# 45501  RANCHIRES09DEL02   23.0      4.9            23.351058
#
#        restaurant_longitude  delivery_latitude  delivery_longitude  \
# 0                 75.892471          22.765049           75.912471
# 1                 77.683237          13.043041           77.813237
# 2                 77.678400          12.924264           77.688400
# 3                 76.976494          11.053669           77.026494
# 4                 80.249982          13.012793           80.289982
# ...                     ...                ...                 ...
# 45497             75.794257          26.912328           75.804257
# 45498                   NaN                NaN                 NaN
# 45499             80.242439          13.052394           80.272439
# 45500             76.986241          11.041753           77.026241
# 45501             85.325731          23.431058           85.405731
#
#        order_date     weather traffic  ...  time_taken city_name order_day  \
# 0      2022-03-19       sunny    high  ...          24      INDO        19
# 1      2022-03-25      stormy     jam  ...          33      BANG        25
# 2      2022-03-19  sandstorms     low  ...          26      BANG        19
# 3      2022-04-05       sunny  medium  ...          21     COIMB         5
# 4      2022-03-26      cloudy    high  ...          30      CHEN        26
# ...           ...         ...     ...  ...         ...       ...       ...
# 45497  2022-03-24       windy    high  ...          32       JAP        24
# 45498  2022-02-16       windy     jam  ...          36       AGR        16
# 45499  2022-03-11      cloudy     low  ...          16      CHEN        11
# 45500  2022-03-07      cloudy    high  ...          26     COIMB         7
# 45501  2022-03-02         fog  medium  ...          36    RANCHI         2
#
#        order_month order_day_of_week is_weekend  pickup_time_minutes  \
# 0                3          saturday          1                 15.0
# 1                3            friday          0                  5.0
# 2                3          saturday          1                 15.0
# 3                4           tuesday          0                 10.0
# 4                3          saturday          1                 15.0
# ...            ...               ...        ...                  ...
# 45497            3          thursday          0                 10.0
# 45498            2         wednesday          0                 15.0
# 45499            3            friday          0                 15.0
# 45500            3            monday          0                  5.0
# 45501            3         wednesday          0                  5.0
#
#       order_time_hour  order_time_of_day   distance
# 0                11.0            morning   3.025149
# 1                19.0            evening  20.183530
# 2                 8.0            morning   1.552758
# 3                18.0            evening   7.790401
# 4                13.0          afternoon   6.210138
# ...               ...                ...        ...
# 45497            11.0            morning   1.489846
# 45498            19.0            evening        NaN
# 45499            23.0              night   4.657195
# 45500            13.0          afternoon   6.232393
# 45501            17.0            evening  12.074396
#
# [45502 rows x 26 columns]

# %%
cleaned_data_load.select_dtypes(include="object").columns.tolist()
# Out:
# ['rider_id',
#  'order_date',
#  'weather',
#  'traffic',
#  'type_of_order',
#  'type_of_vehicle',
#  'festival',
#  'city_type',
#  'city_name',
#  'order_day_of_week',
#  'order_time_of_day']

# %%
cleaned_data_load.select_dtypes(include=['float']).columns.tolist()
# Out:
# ['age',
#  'ratings',
#  'restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude',
#  'multiple_deliveries',
#  'pickup_time_minutes',
#  'order_time_hour',
#  'distance']

# %%
cleaned_data_load.select_dtypes(include=['float']).columns.get_indexer().tolist()

# %%
cleaned_data_load.select_dtypes(include=['number']).columns.tolist()
# Out:
# ['age',
#  'ratings',
#  'restaurant_latitude',
#  'restaurant_longitude',
#  'delivery_latitude',
#  'delivery_longitude',
#  'vehicle_condition',
#  'multiple_deliveries',
#  'time_taken',
#  'order_day',
#  'order_month',
#  'is_weekend',
#  'pickup_time_minutes',
#  'order_time_hour',
#  'distance']

# %%
cleaned_data_load.select_dtypes(include="int").columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1469957412.py in <cell line: 0>()
# ----> 1 cleaned_data_load.select_dtypes(include="int").columns.tolist()
#
# NameError: name 'cleaned_data_load' is not defined
